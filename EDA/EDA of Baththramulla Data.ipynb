# %% [markdown]
# # EDA of baththramulla

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2019 - 2021

# %%
df1 = pd.read_excel("../Data/Data Battaramulla AQMS - 1 Hour - From 2019 to 2021 mid (with NOx).xlsx")

# %%
df1.shape
# Out:
# (21888, 19)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21888 entries, 0 to 21887
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Period Start Time  21888 non-null  datetime64[ns]
#  1   Period End Time    21888 non-null  datetime64[ns]
#  2   AT                 17715 non-null  float64
#  3   RH                 18080 non-null  float64
#  4   BP                 18097 non-null  float64
#  5   Solar Rad          18090 non-null  float64
#  6   Rain Gauge         17502 non-null  float64
#  7   WS Raw             12601 non-null  float64
#  8   WD Raw             18107 non-null  float64
#  9   WS Average         12629 non-null  float64
#  10  WD Average         16668 non-null  float64
#  11  O3 Conc            16664 non-null  float64
#  12  CO Conc            13637 non-null  float64
#  13  NO Conc            17076 non-null  float64
#  14  NO2 Conc           17046 non-null  float64
# ...

# %%
df1.isnull().sum()
# Out:
# Period Start Time       0
# Period End Time         0
# AT                   4173
# RH                   3808
# BP                   3791
# Solar Rad            3798
# Rain Gauge           4386
# WS Raw               9287
# WD Raw               3781
# WS Average           9259
# WD Average           5220
# O3 Conc              5224
# CO Conc              8251
# NO Conc              4812
# NO2 Conc             4842
# NOx Conc             4813
# SO2 Conc             7249
# PM2.5 Conc           5051
# PM10 Conc            5189
# dtype: int64

# %%
df1.describe()
# Out:
#          Period Start Time      Period End Time            AT            RH  \
# count                21888                21888  17715.000000  18080.000000
# mean   2020-03-31 23:30:00  2020-04-01 00:30:00     28.056274     73.349066
# min    2019-01-01 00:00:00  2019-01-01 01:00:00     16.300000     26.780000
# 25%    2019-08-16 23:45:00  2019-08-17 00:45:00     25.800000     64.657500
# 50%    2020-03-31 23:30:00  2020-04-01 00:30:00     27.800000     74.770000
# 75%    2020-11-14 23:15:00  2020-11-15 00:15:00     30.300000     83.520000
# max    2021-06-30 23:00:00  2021-07-01 00:00:00     35.700000     95.040000
# std                    NaN                  NaN      2.760797     12.124024
#
#                  BP     Solar Rad    Rain Gauge        WS Raw        WD Raw  \
# count  18097.000000  18090.000000  17502.000000  12601.000000  18107.000000
# mean    1009.624280    182.031391      0.325871      1.067352    175.341813
# ...

# %% [markdown]
# ## 2022 - 2023

# %%
df2 = pd.read_excel("../Data/Data Battaramulla AQMS - 1 Hour - From 2022-10 Oct to 2023 End (with NOx).xlsx")

# %%
df2.shape
# Out:
# (10968, 19)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10968 entries, 0 to 10967
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Period Start Time  10968 non-null  datetime64[ns]
#  1   Period End Time    10968 non-null  datetime64[ns]
#  2   AT                 3409 non-null   float64
#  3   RH                 8561 non-null   float64
#  4   BP                 8578 non-null   float64
#  5   Solar Rad          8578 non-null   float64
#  6   Rain Gauge         8578 non-null   float64
#  7   WS Raw             0 non-null      float64
#  8   WD Raw             8575 non-null   float64
#  9   WS Average         32 non-null     float64
#  10  WD Average         32 non-null     float64
#  11  O3 Conc            4542 non-null   float64
#  12  CO Conc            4470 non-null   float64
#  13  NO Conc            8047 non-null   float64
#  14  NO2 Conc           8044 non-null   float64
# ...

# %%
df2.isnull().sum()
# Out:
# Period Start Time        0
# Period End Time          0
# AT                    7559
# RH                    2407
# BP                    2390
# Solar Rad             2390
# Rain Gauge            2390
# WS Raw               10968
# WD Raw                2393
# WS Average           10936
# WD Average           10936
# O3 Conc               6426
# CO Conc               6498
# NO Conc               2921
# NO2 Conc              2924
# NOx Conc              2921
# SO2 Conc              3091
# PM2.5 Conc            4848
# PM10 Conc             5399
# dtype: int64

# %%
df2.describe()
# Out:
#                    Period Start Time      Period End Time           AT  \
# count                          10968                10968  3409.000000
# mean   2023-05-17 11:30:00.121827840  2023-05-17 12:30:00    27.846377
# min              2022-10-01 00:00:00  2022-10-01 01:00:00    19.700000
# 25%              2023-01-23 05:45:00  2023-01-23 06:45:00    25.000000
# 50%    2023-05-17 11:30:01.982499840  2023-05-17 12:30:00    27.200000
# 75%              2023-09-08 17:15:00  2023-09-08 18:15:00    30.900000
# max              2023-12-31 23:00:00  2024-01-01 00:00:00    35.700000
# std                              NaN                  NaN     3.356977
#
#                 RH           BP    Solar Rad   Rain Gauge  WS Raw  \
# count  8561.000000  8578.000000  8578.000000  8578.000000     0.0
# mean     74.466213  1010.351819   171.910092     0.391676     NaN
# min      31.000000  1003.900000     0.240000     0.000000     NaN
# ...

# %% [markdown]
# ## 2024

# %%
df3 = pd.read_excel("../Data/Data Battaramulla AQMS - 1 Hour - For 2024 (with NOx).xlsx")

# %%
df3.shape
# Out:
# (8784, 19)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Period Start Time  8784 non-null   datetime64[ns]
#  1   Period End Time    8784 non-null   datetime64[ns]
#  2   AT                 0 non-null      float64
#  3   RH                 6874 non-null   float64
#  4   BP                 6893 non-null   float64
#  5   Solar Rad          4123 non-null   float64
#  6   Rain Gauge         6893 non-null   float64
#  7   WS Raw             0 non-null      float64
#  8   WD Raw             6893 non-null   float64
#  9   WS Average         28 non-null     float64
#  10  WD Average         32 non-null     float64
#  11  O3 Conc            3901 non-null   float64
#  12  CO Conc            2087 non-null   float64
#  13  NO Conc            6515 non-null   float64
#  14  NO2 Conc           6514 non-null   float64
# ...

# %%
df3.isnull().sum()
# Out:
# Period Start Time       0
# Period End Time         0
# AT                   8784
# RH                   1910
# BP                   1891
# Solar Rad            4661
# Rain Gauge           1891
# WS Raw               8784
# WD Raw               1891
# WS Average           8756
# WD Average           8752
# O3 Conc              4883
# CO Conc              6697
# NO Conc              2269
# NO2 Conc             2270
# NOx Conc             2269
# SO2 Conc             2319
# PM2.5 Conc           2468
# PM10 Conc            6291
# dtype: int64

# %%
df3.describe()
# Out:
#          Period Start Time      Period End Time   AT           RH  \
# count                 8784                 8784  0.0  6874.000000
# mean   2024-07-01 23:30:00  2024-07-02 00:30:00  NaN    74.804289
# min    2024-01-01 00:00:00  2024-01-01 01:00:00  NaN    35.100000
# 25%    2024-04-01 11:45:00  2024-04-01 12:45:00  NaN    65.860000
# 50%    2024-07-01 23:30:00  2024-07-02 00:30:00  NaN    76.765000
# 75%    2024-10-01 11:15:00  2024-10-01 12:15:00  NaN    85.247500
# max    2024-12-31 23:00:00  2025-01-01 00:00:00  NaN    93.190000
# std                    NaN                  NaN  NaN    12.237718
#
#                 BP    Solar Rad   Rain Gauge  WS Raw       WD Raw  WS Average  \
# count  6893.000000  4123.000000  6893.000000     0.0  6893.000000   28.000000
# mean   1009.818134   168.078113     0.361787     NaN   179.918062    0.210714
# min    1003.600000     0.000000     0.000000     NaN    55.100000    0.000000
# ...

# %% [markdown]
# ## Concat dataframe

# %%
df_combined = pd.concat([df1,df2,df3],ignore_index=True)

# %%
df_combined.shape
# Out:
# (41640, 19)

# %%
df_combined.head()
# Out:
#     Period Start Time     Period End Time    AT     RH      BP  Solar Rad  \
# 0 2019-01-01 00:00:00 2019-01-01 01:00:00  24.9  72.74  1014.7       0.25
# 1 2019-01-01 01:00:00 2019-01-01 02:00:00  24.4  74.36  1014.2       0.26
# 2 2019-01-01 02:00:00 2019-01-01 03:00:00  24.2  75.32  1013.7       0.25
# 3 2019-01-01 03:00:00 2019-01-01 04:00:00  24.2  74.25  1013.3       0.25
# 4 2019-01-01 04:00:00 2019-01-01 05:00:00  24.0  73.47  1013.0       0.25
#
#    Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 0         0.0     1.6   165.8         1.4         2.4    34.19    497.0
# 1         0.0     1.8   179.7         1.6       357.9    36.08    339.0
# 2         0.0     2.0   197.1         1.6       353.3    36.22      NaN
# 3         0.0     2.1   190.1         1.7       357.9    36.96    295.0
# 4         0.0     2.1   167.5         1.8         3.0    37.39    305.0
#
#    NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# ...

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41640 entries, 0 to 41639
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Period Start Time  41640 non-null  datetime64[ns]
#  1   Period End Time    41640 non-null  datetime64[ns]
#  2   AT                 21124 non-null  float64
#  3   RH                 33515 non-null  float64
#  4   BP                 33568 non-null  float64
#  5   Solar Rad          30791 non-null  float64
#  6   Rain Gauge         32973 non-null  float64
#  7   WS Raw             12601 non-null  float64
#  8   WD Raw             33575 non-null  float64
#  9   WS Average         12689 non-null  float64
#  10  WD Average         16732 non-null  float64
#  11  O3 Conc            25107 non-null  float64
#  12  CO Conc            20194 non-null  float64
#  13  NO Conc            31638 non-null  float64
#  14  NO2 Conc           31604 non-null  float64
# ...

# %%
df_combined.describe()
# Out:
#                    Period Start Time                Period End Time  \
# count                          41640                          41640
# mean   2021-12-20 06:11:17.496066560  2021-12-20 07:11:17.463976960
# min              2019-01-01 00:00:00            2019-01-01 01:00:00
# 25%              2020-03-09 17:45:00            2020-03-09 18:45:00
# 50%              2021-05-17 11:30:00            2021-05-17 12:30:00
# 75%              2023-10-25 05:15:00            2023-10-25 06:15:00
# max              2024-12-31 23:00:00            2025-01-01 00:00:00
# std                              NaN                            NaN
#
#                  AT            RH            BP     Solar Rad    Rain Gauge  \
# count  21124.000000  33515.000000  33568.000000  30791.000000  32973.000000
# mean      28.022401     73.932897   1009.850003    177.343337      0.350499
# min       16.300000     26.780000    976.400000      0.000000      0.000000
# ...

# %%
df_combined.isnull().sum()
# Out:
# Period Start Time        0
# Period End Time          0
# AT                   20516
# RH                    8125
# BP                    8072
# Solar Rad            10849
# Rain Gauge            8667
# WS Raw               29039
# WD Raw                8065
# WS Average           28951
# WD Average           24908
# O3 Conc              16533
# CO Conc              21446
# NO Conc              10002
# NO2 Conc             10036
# NOx Conc             10003
# SO2 Conc             12659
# PM2.5 Conc           12367
# PM10 Conc            16879
# dtype: int64

# %% [markdown]
# # EDA of Individual data

# %% [markdown]
# ## Weather Data

# %% [markdown]
# ### Period Start Time

# %%
df_combined['Period Start Time'].value_counts()
# Out:
# Period Start Time
# 2019-01-01 00:00:00    1
# 2023-06-03 04:00:00    1
# 2023-06-02 10:00:00    1
# 2023-06-02 11:00:00    1
# 2023-06-02 12:00:00    1
#                       ..
# 2020-08-01 10:00:00    1
# 2020-08-01 11:00:00    1
# 2020-08-01 12:00:00    1
# 2020-08-01 13:00:00    1
# 2024-12-31 23:00:00    1
# Name: count, Length: 41640, dtype: int64

# %% [markdown]
# ### Period End Time

# %%
df_combined['Period End Time'].value_counts()
# Out:
# Period End Time
# 2019-01-01 01:00:00    1
# 2023-06-03 05:00:00    1
# 2023-06-02 11:00:00    1
# 2023-06-02 12:00:00    1
# 2023-06-02 13:00:00    1
#                       ..
# 2020-08-01 11:00:00    1
# 2020-08-01 12:00:00    1
# 2020-08-01 13:00:00    1
# 2020-08-01 14:00:00    1
# 2025-01-01 00:00:00    1
# Name: count, Length: 41640, dtype: int64

# %% [markdown]
# ### AT

# %%
df_combined['AT'].value_counts()
# Out:
# AT
# 25.1    294
# 26.2    288
# 25.4    275
# 27.5    272
# 26.6    271
#        ...
# 20.6      1
# 19.3      1
# 19.2      1
# 18.2      1
# 17.3      1
# Name: count, Length: 176, dtype: int64

# %%
df_combined['AT'].describe()
# Out:
# count    21124.000000
# mean        28.022401
# std          2.866367
# min         16.300000
# 25%         25.700000
# 50%         27.800000
# 75%         30.400000
# max         35.700000
# Name: AT, dtype: float64

# %%
sns.histplot(df_combined['AT'])
# Out:
# <Axes: xlabel='AT', ylabel='Count'>

# %%
df_combined[df_combined['AT'] == 16.3]
# Out:
#        Period Start Time     Period End Time    AT     RH      BP  Solar Rad  \
# 4010 2019-06-17 02:00:00 2019-06-17 03:00:00  16.3  84.27  1008.8       0.27
#
#       Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 4010         0.0     0.0    89.2         0.0        78.8      2.4    563.0
#
#       NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# 4010     2.81      8.04     10.86       4.7        13.0       30.0

# %% [markdown]
# ### RH

# %%
df_combined['RH'].value_counts()
# Out:
# RH
# 87.61    23
# 76.58    21
# 89.02    20
# 77.61    20
# 89.57    20
#          ..
# 50.30     1
# 44.90     1
# 45.93     1
# 47.37     1
# 49.80     1
# Name: count, Length: 5045, dtype: int64

# %%
sns.histplot(df_combined['RH'])
# Out:
# <Axes: xlabel='RH', ylabel='Count'>

# %%
df_combined.columns
# Out:
# Index(['Period Start Time', 'Period End Time', 'AT', 'RH', 'BP', 'Solar Rad',
#        'Rain Gauge', 'WS Raw', 'WD Raw', 'WS Average', 'WD Average', 'O3 Conc',
#        'CO Conc', 'NO Conc', 'NO2 Conc', 'NOx Conc', 'SO2 Conc', 'PM2.5 Conc',
#        'PM10 Conc'],
#       dtype='object')

# %% [markdown]
# ### BP

# %%
df_combined['BP'].value_counts()
# Out:
# BP
# 1009.2    680
# 1009.4    666
# 1010.3    659
# 1010.2    646
# 1009.7    642
#          ...
# 976.4       1
# 988.0       1
# 1016.9      1
# 1016.6      1
# 1017.0      1
# Name: count, Length: 137, dtype: int64

# %% [markdown]
# ### Solar Rad

# %%
df_combined['Solar Rad'].value_counts()
# Out:
# Solar Rad
# 0.28      2129
# 0.27      1962
# 0.29      1870
# 0.26      1830
# 0.25      1514
#           ...
# 456.39       1
# 118.91       1
# 40.37        1
# 174.92       1
# 1.56         1
# Name: count, Length: 14510, dtype: int64

# %%
df_combined['Solar Rad'].describe()
# Out:
# count    30791.000000
# mean       177.343337
# std        244.890616
# min          0.000000
# 25%          0.280000
# 50%          8.420000
# 75%        342.825000
# max        961.300000
# Name: Solar Rad, dtype: float64

# %% [markdown]
# ### Rain Gauge

# %%
df_combined['Rain Gauge'].value_counts()
# Out:
# Rain Gauge
# 0.0     29533
# 0.2       894
# 0.4       374
# 0.6       220
# 0.8       181
#         ...
# 22.8        1
# 52.0        1
# 27.0        1
# 32.8        1
# 18.0        1
# Name: count, Length: 176, dtype: int64

# %% [markdown]
# ### WS Raw

# %%
df_combined['WS Raw'].value_counts()
# Out:
# WS Raw
# 0.0    1394
# 0.5     748
# 0.4     720
# 0.6     673
# 0.3     662
# 0.2     656
# 0.7     598
# 0.1     557
# 0.8     482
# 0.9     451
# 1.0     423
# 1.1     402
# 1.2     350
# 1.4     293
# 1.3     291
# 1.5     288
# 2.6     284
# 2.3     282
# 2.5     281
# 1.6     276
# 2.4     276
# 2.1     265
# 2.2     250
# 1.9     239
# 1.8     237
# 2.7     235
# 1.7     232
# 2.0     229
# 2.8     168
# 2.9     113
# 3.0      70
# 3.1      53
# 3.3      30
# 3.2      26
# 3.4      15
# 3.6      13
# 3.5       7
# 3.8       6
# 3.7       5
# 3.9       4
# 4.0       3
# 4.1       2
# 4.2       2
# 5.1       2
# 4.6       2
# 6.0       1
# 4.9       1
# 6.3       1
# 5.3       1
# 5.9       1
# 4.8       1
# Name: count, dtype: int64

# %% [markdown]
# ### WD Raw

# %%
df_combined['WD Raw'].value_counts()
# Out:
# WD Raw
# 90.3     60
# 89.2     52
# 86.8     51
# 87.7     50
# 86.7     48
#          ..
# 73.7      1
# 66.2      1
# 70.2      1
# 70.0      1
# 294.4     1
# Name: count, Length: 2275, dtype: int64

# %% [markdown]
# ## Pollutant

# %% [markdown]
# ### O3 Conc

# %%
df_combined['O3 Conc'].value_counts()
# Out:
# O3 Conc
# 0.00     81
# 1.96     36
# 1.74     32
# 1.77     31
# 2.17     31
#          ..
# 26.00     1
# 34.22     1
# 35.87     1
# 23.25     1
# 36.82     1
# Name: count, Length: 4572, dtype: int64

# %%
sns.histplot(df_combined['O3 Conc'])
# Out:
# <Axes: xlabel='O3 Conc', ylabel='Count'>

# %%
df_combined['O3 Conc'].describe()
# Out:
# count    25107.000000
# mean        13.360517
# std         11.966432
# min         -1.930000
# 25%          4.640000
# 50%          9.930000
# 75%         17.890000
# max         92.640000
# Name: O3 Conc, dtype: float64

# %%
df_combined[df_combined['O3 Conc'] == -1.93]
# Out:
#         Period Start Time     Period End Time  AT     RH      BP  Solar Rad  \
# 38610 2024-08-27 18:00:00 2024-08-27 19:00:00 NaN  70.89  1011.0        NaN
#
#        Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 38610         0.0     NaN   224.2         NaN         NaN    -1.93      NaN
#
#        NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# 38610      NaN       NaN       NaN      2.41         NaN        NaN

# %% [markdown]
# ### CO Conc

# %%
df_combined['CO Conc'].value_counts()
# Out:
# CO Conc
# 483.00    13
# 615.00    10
# 714.00     9
# 415.00     9
# 572.00     9
#           ..
# 458.25     1
# 544.78     1
# 521.30     1
# 509.36     1
# 147.65     1
# Name: count, Length: 16981, dtype: int64

# %%
sns.histplot(df_combined['CO Conc'])
# Out:
# <Axes: xlabel='CO Conc', ylabel='Count'>

# %%
df_combined['CO Conc'].describe()
# Out:
# count    20194.000000
# mean       519.657931
# std        367.121060
# min         35.320000
# 25%        294.725000
# 50%        426.000000
# 75%        635.935000
# max       4559.000000
# Name: CO Conc, dtype: float64

# %% [markdown]
# ### NO Conc

# %%
df_combined['NO Conc'].value_counts()
# Out:
# NO Conc
# 0.17     129
# 0.35     126
# 0.18     121
# 0.36     117
# 0.28     110
#         ...
# 27.53      1
# 37.22      1
# 21.99      1
# 52.64      1
# 22.05      1
# Name: count, Length: 3609, dtype: int64

# %%
sns.histplot(df_combined['NO Conc'])
# Out:
# <Axes: xlabel='NO Conc', ylabel='Count'>

# %%
df_combined['NO Conc'].describe()
# Out:
# count    31638.000000
# mean         5.596364
# std          9.095636
# min         -4.790000
# 25%          0.650000
# 50%          2.160000
# 75%          6.130000
# max        240.350000
# Name: NO Conc, dtype: float64

# %% [markdown]
# ### NO2 Conc

# %%
df_combined['NO2 Conc'].value_counts()
# Out:
# NO2 Conc
# 0.00     75
# 5.87     36
# 5.53     36
# 5.81     36
# 3.03     35
#          ..
# 38.36     1
# 39.70     1
# 35.54     1
# 41.29     1
# 24.97     1
# Name: count, Length: 3521, dtype: int64

# %%
sns.histplot(df_combined['NO2 Conc'])
# Out:
# <Axes: xlabel='NO2 Conc', ylabel='Count'>

# %%
df_combined['NO2 Conc'].describe()
# Out:
# count    31604.000000
# mean        10.127867
# std          7.872557
# min         -0.450000
# 25%          4.370000
# 50%          7.940000
# 75%         14.110000
# max         57.080000
# Name: NO2 Conc, dtype: float64

# %%
df_combined[df_combined['NO2 Conc'] == -0.45]
# Out:
#         Period Start Time     Period End Time  AT     RH      BP  Solar Rad  \
# 35801 2024-05-02 17:00:00 2024-05-02 18:00:00 NaN  69.28  1006.0      71.26
#
#        Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 35801         0.0     NaN   207.0         NaN         NaN      NaN      NaN
#
#        NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# 35801     7.94     -0.45      7.41      9.71        14.0        NaN

# %% [markdown]
# ### NOx Conc

# %%
df_combined['NOx Conc'].value_counts()
# Out:
# NOx Conc
# 6.75     31
# 7.00     30
# 6.44     30
# 9.18     29
# 7.46     29
#          ..
# 29.45     1
# 42.06     1
# 31.52     1
# 44.22     1
# 42.57     1
# Name: count, Length: 5453, dtype: int64

# %%
sns.histplot(df_combined['NOx Conc'])
# Out:
# <Axes: xlabel='NOx Conc', ylabel='Count'>

# %%
df_combined['NOx Conc'].describe()
# Out:
# count    31637.000000
# mean        15.723119
# std         14.577447
# min         -0.400000
# 25%          6.070000
# 50%         11.030000
# 75%         20.990000
# max        255.340000
# Name: NOx Conc, dtype: float64

# %%
df_combined[ df_combined['NOx Conc'] == -0.4 ]
# Out:
#         Period Start Time     Period End Time  AT     RH      BP  Solar Rad  \
# 35868 2024-05-05 12:00:00 2024-05-05 13:00:00 NaN  58.67  1007.5     557.06
#
#        Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 35868         0.0     NaN   235.2         NaN         NaN      NaN      NaN
#
#        NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# 35868    -1.55      1.16      -0.4      10.1        17.0        NaN

# %% [markdown]
# ### SO2 Conc

# %%
df_combined['SO2 Conc'].value_counts()
# Out:
# SO2 Conc
# 4.20     65
# 4.06     64
# 3.92     62
# 5.30     61
# 4.30     59
#          ..
# 20.84     1
# 17.02     1
# 47.83     1
# 22.18     1
# 1.05      1
# Name: count, Length: 2069, dtype: int64

# %%
sns.histplot(df_combined['SO2 Conc'])
# Out:
# <Axes: xlabel='SO2 Conc', ylabel='Count'>

# %%
df_combined['SO2 Conc'].describe()
# Out:
# count    28981.000000
# mean         7.528441
# std          4.224653
# min          0.150000
# 25%          4.650000
# 50%          6.250000
# 75%          9.680000
# max         75.040000
# Name: SO2 Conc, dtype: float64

# %% [markdown]
# ### PM2.5 Conc

# %%
df_combined['PM2.5 Conc'].value_counts()
# Out:
# PM2.5 Conc
# 6.0      1014
# 8.0      1006
# 9.0       951
# 11.0      951
# 10.0      942
#          ...
# 122.0       1
# 114.0       1
# 115.0       1
# 118.0       1
# 109.0       1
# Name: count, Length: 129, dtype: int64

# %%
sns.histplot(df_combined['PM2.5 Conc'])
# Out:
# <Axes: xlabel='PM2.5 Conc', ylabel='Count'>

# %%
df_combined['PM2.5 Conc'].describe()
# Out:
# count    29273.000000
# mean        23.062481
# std         17.174139
# min         -4.000000
# 25%         10.000000
# 50%         19.000000
# 75%         32.000000
# max        142.000000
# Name: PM2.5 Conc, dtype: float64

# %%
df_combined[df_combined['PM2.5 Conc'] == -4]
# Out:
#         Period Start Time     Period End Time  AT     RH      BP  Solar Rad  \
# 30618 2023-09-29 18:00:00 2023-09-29 19:00:00 NaN  88.91  1011.6       0.33
# 30619 2023-09-29 19:00:00 2023-09-29 20:00:00 NaN  92.09  1012.2       0.29
# 30625 2023-09-30 01:00:00 2023-09-30 02:00:00 NaN  92.20  1011.5       0.31
# 30626 2023-09-30 02:00:00 2023-09-30 03:00:00 NaN  92.09  1011.0       0.31
# 30754 2023-10-05 10:00:00 2023-10-05 11:00:00 NaN  84.40  1012.6     315.33
# 30771 2023-10-06 03:00:00 2023-10-06 04:00:00 NaN  90.18  1009.4       0.29
# 30983 2023-10-14 23:00:00 2023-10-15 00:00:00 NaN  90.32  1013.7       0.30
#
#        Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  CO Conc  \
# 30618        18.8     NaN   269.7         NaN         NaN      NaN   272.43
# 30619         0.6     NaN   234.8         NaN         NaN      NaN   286.80
# 30625         2.6     NaN    80.7         NaN         NaN      NaN      NaN
# ...

# %% [markdown]
# ### PM10 Conc

# %%
df_combined['PM10 Conc'].value_counts()
# Out:
# PM10 Conc
# 27.0     750
# 17.0     681
# 22.0     637
# 23.0     635
# 26.0     621
#         ...
# 160.0      1
# 164.0      1
# 177.0      1
# 197.0      1
# 0.0        1
# Name: count, Length: 180, dtype: int64

# %%
sns.histplot(df_combined['PM10 Conc'])
# Out:
# <Axes: xlabel='PM10 Conc', ylabel='Count'>

# %%
df_combined['PM10 Conc'].describe()
# Out:
# count    24761.000000
# mean        36.132709
# std         21.756105
# min          0.000000
# 25%         21.000000
# 50%         31.000000
# 75%         45.000000
# max        218.000000
# Name: PM10 Conc, dtype: float64

# %%
df_combined[df_combined['PM10 Conc'] == 0]
# Out:
#             Period Start Time     Period End Time  AT     RH      BP  \
# 27081 2023-05-05 09:00:00.530 2023-05-05 10:00:00 NaN  91.39  1011.5
#
#        Solar Rad  Rain Gauge  WS Raw  WD Raw  WS Average  WD Average  O3 Conc  \
# 27081     115.27         1.6     NaN   134.4         NaN         NaN     5.03
#
#        CO Conc  NO Conc  NO2 Conc  NOx Conc  SO2 Conc  PM2.5 Conc  PM10 Conc
# 27081   544.71      0.5      0.97      1.47     11.19         NaN        0.0

# %% [markdown]
# # Checking data with the Time

# %% [markdown]
# ## Weather Data

# %% [markdown]
# ### AT

# %%
df_at_time = df_combined[['Period Start Time','AT']]

# %%
df_at_time
# Out:
#         Period Start Time    AT
# 0     2019-01-01 00:00:00  24.9
# 1     2019-01-01 01:00:00  24.4
# 2     2019-01-01 02:00:00  24.2
# 3     2019-01-01 03:00:00  24.2
# 4     2019-01-01 04:00:00  24.0
# ...                   ...   ...
# 41635 2024-12-31 19:00:00   NaN
# 41636 2024-12-31 20:00:00   NaN
# 41637 2024-12-31 21:00:00   NaN
# 41638 2024-12-31 22:00:00   NaN
# 41639 2024-12-31 23:00:00   NaN
#
# [41640 rows x 2 columns]

# %%
df_at_time.isnull().sum()
# Out:
# Period Start Time        0
# AT                   20516
# dtype: int64

# %%
sns.histplot(df_at_time)
# Out:
# <Axes: ylabel='Count'>

# %%
df_at_time['Period Start Time'].describe()
# Out:
# count                            41640
# mean     2021-12-20 06:11:17.496066560
# min                2019-01-01 00:00:00
# 25%                2020-03-09 17:45:00
# 50%                2021-05-17 11:30:00
# 75%                2023-10-25 05:15:00
# max                2024-12-31 23:00:00
# Name: Period Start Time, dtype: object

# %%
df_at_time['Period Start Time'] = pd.to_datetime(df_at_time['Period Start Time'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\107177401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_at_time['Period Start Time'] = pd.to_datetime(df_at_time['Period Start Time'])

# %%
df_at_time['Period Start Time']
# Out:
# 0       2019-01-01 00:00:00
# 1       2019-01-01 01:00:00
# 2       2019-01-01 02:00:00
# 3       2019-01-01 03:00:00
# 4       2019-01-01 04:00:00
#                 ...
# 41635   2024-12-31 19:00:00
# 41636   2024-12-31 20:00:00
# 41637   2024-12-31 21:00:00
# 41638   2024-12-31 22:00:00
# 41639   2024-12-31 23:00:00
# Name: Period Start Time, Length: 41640, dtype: datetime64[ns]

# %%
df_at_time['Date'] = df_at_time['Period Start Time'].dt.date
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3553069315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_at_time['Date'] = df_at_time['Period Start Time'].dt.date

# %%
df_at_time
# Out:
#         Period Start Time    AT        Date
# 0     2019-01-01 00:00:00  24.9  2019-01-01
# 1     2019-01-01 01:00:00  24.4  2019-01-01
# 2     2019-01-01 02:00:00  24.2  2019-01-01
# 3     2019-01-01 03:00:00  24.2  2019-01-01
# 4     2019-01-01 04:00:00  24.0  2019-01-01
# ...                   ...   ...         ...
# 41635 2024-12-31 19:00:00   NaN  2024-12-31
# 41636 2024-12-31 20:00:00   NaN  2024-12-31
# 41637 2024-12-31 21:00:00   NaN  2024-12-31
# 41638 2024-12-31 22:00:00   NaN  2024-12-31
# 41639 2024-12-31 23:00:00   NaN  2024-12-31
#
# [41640 rows x 3 columns]

# %%
df_filtered1 = df_at_time[(df_at_time['Period Start Time'].dt.year >= 2019) &
                         (df_at_time['Period Start Time'].dt.year <= 2024)]

# %%
daily_at = df_filtered1.groupby('Date')['AT'].mean().reset_index()

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='AT', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean AT from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean AT')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_feb_2019 = df_at_time[
    (df_at_time['Period Start Time'].dt.year == 2019) &
    (df_at_time['Period Start Time'].dt.month == 2)
]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_feb_2019, x='Date', y='AT', marker='o')
plt.title('Daily AT - Feburary 2019')
plt.xlabel('Date')
plt.ylabel('Ambient Temp')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_mar_2019 = df_at_time[
    (df_at_time['Period Start Time'].dt.year == 2019) &
    (df_at_time['Period Start Time'].dt.month == 3)
]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df_mar_2019, x='Date', y='AT', marker='o')
plt.title('Daily AT - March 2019')
plt.xlabel('Date')
plt.ylabel('Ambient Temp')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2019 June

# %%
df_jun_2019 = df_at_time[
    (df_at_time['Period Start Time'].dt.year == 2019) &
    (df_at_time['Period Start Time'].dt.month == 6)
]

plt.figure(figsize=(10, 5))
sns.lineplot(data=df_jun_2019, x='Date', y='AT', marker='o')
plt.title('Daily AT - March 2019')
plt.xlabel('Date')
plt.ylabel('Ambient Temp')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### RH

# %%
df_rh_time = df_combined[['Period Start Time','RH']]

# %%
df_rh_time
# Out:
#         Period Start Time     RH
# 0     2019-01-01 00:00:00  72.74
# 1     2019-01-01 01:00:00  74.36
# 2     2019-01-01 02:00:00  75.32
# 3     2019-01-01 03:00:00  74.25
# 4     2019-01-01 04:00:00  73.47
# ...                   ...    ...
# 41635 2024-12-31 19:00:00  86.14
# 41636 2024-12-31 20:00:00  87.52
# 41637 2024-12-31 21:00:00  86.71
# 41638 2024-12-31 22:00:00  80.01
# 41639 2024-12-31 23:00:00  81.37
#
# [41640 rows x 2 columns]

# %%
df_rh_time.isnull().sum()
# Out:
# Period Start Time       0
# RH                   8125
# dtype: int64

# %%
sns.histplot(df_rh_time)
# Out:
# <Axes: ylabel='Count'>

# %%
df_rh_time['Date'] = df_rh_time['Period Start Time'].dt.date
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\2645537198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rh_time['Date'] = df_rh_time['Period Start Time'].dt.date

# %%
df_rh_time
# Out:
#         Period Start Time     RH        Date
# 0     2019-01-01 00:00:00  72.74  2019-01-01
# 1     2019-01-01 01:00:00  74.36  2019-01-01
# 2     2019-01-01 02:00:00  75.32  2019-01-01
# 3     2019-01-01 03:00:00  74.25  2019-01-01
# 4     2019-01-01 04:00:00  73.47  2019-01-01
# ...                   ...    ...         ...
# 41635 2024-12-31 19:00:00  86.14  2024-12-31
# 41636 2024-12-31 20:00:00  87.52  2024-12-31
# 41637 2024-12-31 21:00:00  86.71  2024-12-31
# 41638 2024-12-31 22:00:00  80.01  2024-12-31
# 41639 2024-12-31 23:00:00  81.37  2024-12-31
#
# [41640 rows x 3 columns]

# %%
df_filtered2 = df_rh_time[(df_rh_time['Period Start Time'].dt.year >= 2019) &
                         (df_rh_time['Period Start Time'].dt.year <= 2024)]

# %%
daily_at = df_filtered2.groupby('Date')['RH'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='RH', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean RH from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean AT')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BP

# %%
df_bp_time = df_combined[['Period Start Time','BP']]

df_bp_time['Date'] = df_bp_time['Period Start Time'].dt.date

df_filtered3 = df_bp_time[(df_bp_time['Period Start Time'].dt.year >= 2019) &
                         (df_bp_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered3.groupby('Date')['BP'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='BP', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean BP from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean AT')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\1301239178.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bp_time['Date'] = df_bp_time['Period Start Time'].dt.date

# %%
df_combined.columns
# Out:
# Index(['Period Start Time', 'Period End Time', 'AT', 'RH', 'BP', 'Solar Rad',
#        'Rain Gauge', 'WS Raw', 'WD Raw', 'WS Average', 'WD Average', 'O3 Conc',
#        'CO Conc', 'NO Conc', 'NO2 Conc', 'NOx Conc', 'SO2 Conc', 'PM2.5 Conc',
#        'PM10 Conc'],
#       dtype='object')

# %% [markdown]
# ### Solar Rad

# %%
df_sr_time = df_combined[['Period Start Time','Solar Rad']]

df_sr_time['Date'] = df_sr_time['Period Start Time'].dt.date

df_filtered = df_sr_time[(df_sr_time['Period Start Time'].dt.year >= 2019) &
                         (df_sr_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['Solar Rad'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='Solar Rad', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean Solar Rad from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean AT')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\2867614485.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sr_time['Date'] = df_sr_time['Period Start Time'].dt.date

# %% [markdown]
# ### Rain Gauge

# %%
df_rg_time = df_combined[['Period Start Time','Rain Gauge']]

df_rg_time['Date'] = df_rg_time['Period Start Time'].dt.date

df_filtered = df_rg_time[(df_rg_time['Period Start Time'].dt.year >= 2019) &
                         (df_rg_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['Rain Gauge'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='Rain Gauge', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean Rain Gauge from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3464914658.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rg_time['Date'] = df_rg_time['Period Start Time'].dt.date

# %% [markdown]
# ### WS Raw

# %%
df_ws_time = df_combined[['Period Start Time','WS Raw']]

df_ws_time['Date'] = df_ws_time['Period Start Time'].dt.date

df_filtered = df_ws_time[(df_ws_time['Period Start Time'].dt.year >= 2019) &
                         (df_ws_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['WS Raw'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='WS Raw', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean WS Raw from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\4183498629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ws_time['Date'] = df_ws_time['Period Start Time'].dt.date

# %% [markdown]
# ### WD Raw

# %%
df_wd_time = df_combined[['Period Start Time','WD Raw']]

df_wd_time['Date'] = df_wd_time['Period Start Time'].dt.date

df_filtered = df_wd_time[(df_wd_time['Period Start Time'].dt.year >= 2019) &
                         (df_wd_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['WD Raw'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='WD Raw', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean WD Raw from 2019 to 2024')
plt.xlabel('Date')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\238246900.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wd_time['Date'] = df_wd_time['Period Start Time'].dt.date

# %% [markdown]
# ## Pollutant

# %% [markdown]
# ### O3 Conc

# %%
df_o3_time = df_combined[['Period Start Time','O3 Conc']]

df_o3_time['Date'] = df_o3_time['Period Start Time'].dt.date

df_filtered = df_o3_time[(df_o3_time['Period Start Time'].dt.year >= 2019) &
                         (df_o3_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['O3 Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='O3 Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean O3 Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3337125414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_o3_time['Date'] = df_o3_time['Period Start Time'].dt.date

# %% [markdown]
# ### CO Conc

# %%
df_co_time = df_combined[['Period Start Time','CO Conc']]

df_co_time['Date'] = df_co_time['Period Start Time'].dt.date

df_filtered = df_co_time[(df_co_time['Period Start Time'].dt.year >= 2019) &
                         (df_co_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['CO Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='CO Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean CO Concfrom 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\4209995796.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_co_time['Date'] = df_co_time['Period Start Time'].dt.date

# %% [markdown]
# ### NO Conc

# %%
df_no_time = df_combined[['Period Start Time','NO Conc']]

df_no_time['Date'] = df_no_time['Period Start Time'].dt.date

df_filtered = df_no_time[(df_no_time['Period Start Time'].dt.year >= 2019) &
                         (df_no_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['NO Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='NO Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean NO Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\226339917.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_time['Date'] = df_no_time['Period Start Time'].dt.date

# %% [markdown]
# ### NO2 Conc

# %%
df_no2_time = df_combined[['Period Start Time','NO2 Conc']]

df_no2_time['Date'] = df_no2_time['Period Start Time'].dt.date

df_filtered = df_no2_time[(df_no2_time['Period Start Time'].dt.year >= 2019) &
                         (df_no2_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['NO2 Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='NO2 Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean NO2 Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\2889470596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no2_time['Date'] = df_no2_time['Period Start Time'].dt.date

# %% [markdown]
# ### NOx Conc

# %%
df_nox_time = df_combined[['Period Start Time','NOx Conc']]

df_nox_time['Date'] = df_nox_time['Period Start Time'].dt.date

df_filtered = df_nox_time[(df_nox_time['Period Start Time'].dt.year >= 2019) &
                         (df_nox_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['NOx Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='NOx Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean NOx Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3373938225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nox_time['Date'] = df_nox_time['Period Start Time'].dt.date

# %% [markdown]
# ### SO2 Conc

# %%
df_so2_time = df_combined[['Period Start Time','SO2 Conc']]

df_so2_time['Date'] = df_so2_time['Period Start Time'].dt.date

df_filtered = df_so2_time[(df_so2_time['Period Start Time'].dt.year >= 2019) &
                         (df_so2_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['SO2 Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='SO2 Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean SO2 Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\624684672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_so2_time['Date'] = df_so2_time['Period Start Time'].dt.date

# %% [markdown]
# ### PM2.5 Conc

# %%
df_pm25_time = df_combined[['Period Start Time','PM2.5 Conc']]

df_pm25_time['Date'] = df_pm25_time['Period Start Time'].dt.date

df_filtered = df_pm25_time[(df_pm25_time['Period Start Time'].dt.year >= 2019) &
                         (df_pm25_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['PM2.5 Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='PM2.5 Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean PM2.5 Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\2628990531.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pm25_time['Date'] = df_pm25_time['Period Start Time'].dt.date

# %% [markdown]
# ### PM10 Conc

# %%
df_pm10_time = df_combined[['Period Start Time','PM10 Conc']]

df_pm10_time['Date'] = df_pm10_time['Period Start Time'].dt.date

df_filtered = df_pm10_time[(df_pm10_time['Period Start Time'].dt.year >= 2019) &
                         (df_pm10_time['Period Start Time'].dt.year <= 2024)]

daily_at = df_filtered.groupby('Date')['PM10 Conc'].mean().reset_index()

plt.figure(figsize=(16, 8))
sns.lineplot(x='Date', y='PM10 Conc', data=daily_at, linewidth=0.8)
plt.title('Monthly Mean PM10 Conc from 2019 to 2025')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\2965530273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pm10_time['Date'] = df_pm10_time['Period Start Time'].dt.date
